# %%
#EXERCISE 1

# %%
rm(list = ls())

# %%
#install per directions from tutorial
install.packages('rio')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#read the files from HW3 for exercise
Infant_Mortality=read.csv("https://raw.githubusercontent.com/Fundamentals-Josh/hw4/refs/heads/main/HW%203%20files%20to%20be%20used%20for%20hw4/Infant_Mortality_Formatted2.csv")
Life_Expectantcy=read.csv("https://raw.githubusercontent.com/Fundamentals-Josh/hw4/refs/heads/main/HW%203%20files%20to%20be%20used%20for%20hw4/Life_Expectantcy_Formatted2.csv")
Maternal=read.csv("https://raw.githubusercontent.com/Fundamentals-Josh/hw4/refs/heads/main/HW%203%20files%20to%20be%20used%20for%20hw4/Maternal_Formatted2.csv")

# %%
#display column names to verify that files are being read successfully.  Also confirming data types as part of this chunk.
names(Infant_Mortality)
names(Life_Expectantcy)
names(Maternal)

str(Infant_Mortality)
str(Life_Expectantcy)
str(Maternal)
# Out:
# [1] "Country"              "Infant_Deaths_Per_1K" "Region"
# [1] "Country"                "Expected_Years_To_Live" "Region"
# [1] "Country"                     "Deaths_Per_100K_Live_Births"
# [3] "Region"
# 'data.frame':	227 obs. of  3 variables:
#  $ Country             : chr  "Afghanistan" "Somalia" "Central African Republic" "Equatorial Guinea" ...
#  $ Infant_Deaths_Per_1K: num  101.3 83.6 80.5 77.4 71.2 ...
#  $ Region              : chr  "South Asia" "Africa" "Africa" "Africa" ...
# 'data.frame':	227 obs. of  3 variables:
#  $ Country               : chr  "Monaco" "Singapore" "Macau" "Japan" ...
#  $ Expected_Years_To_Live: num  89.8 86.7 85.3 85.2 84.2 84.2 84 84 83.9 83.8 ...
#  $ Region                : chr  "Europe" "East and Southeast Asia" "East and Southeast Asia" "East and Southeast Asia" ...
# 'data.frame':	196 obs. of  3 variables:
#  $ Country                    : chr  "Nigeria" "Chad" "South Sudan" "Central African Republic" ...
#  $ Deaths_Per_100K_Live_Births: int  993 748 692 692 628 563 521 518 505 494 ...
#  $ Region                     : chr  "Africa" "Africa" "Africa" "Africa" ...

# %%
#merging all three data frames together. Need a primary key for this to succeeed, so using country. The merge needs to be completed in two steps, because you can only merge two at a time.
merged_data <- merge(Infant_Mortality, Life_Expectantcy, by = "Country")
final_merged_data <- merge(merged_data, Maternal, by = "Country")

#showing a printout to see the result.
final_merged_data
# Out:
#     Country                Infant_Deaths_Per_1K
# 1   Afghanistan            101.3
# 2   Albania                 10.3
# 3   Algeria                 18.7
# 4   Andorra                  3.3
# 5   Angola                  55.6
# 6   Antigua and Barbuda     13.6
# 7   Argentina                9.0
# 8   Armenia                 11.6
# 9   Australia                2.9
# 10  Austria                  3.2
# 11  Azerbaijan              10.9
# 12  Bahrain                  9.7
# 13  Bangladesh              28.8
# 14  Barbados                 9.6
# 15  Belarus                  2.1
# 16  Belgium                  3.1
# 17  Belize                  11.3
# 18  Benin                   52.9
# 19  Bhutan                  24.3
# 20  Bolivia                 22.3
# 21  Bosnia and Herzegovina   5.0
# 22  Botswana                23.7
# 23  Brazil                  12.9
# 24  Brunei                  10.0
# 25  Bulgaria                 7.7
# 26  Burkina Faso            47.0
# 27  Burma                   32.1
# 28  Burundi                 35.7
# 29  Cabo Verde              22.4
# 30  Cambodia                27.9
# ⋮   ⋮                      ⋮
# 167 Suriname               29.6
# 168 Sweden                  2.3
# 169 Switzerland             3.0
# 170 Syria                  15.1
# 171 Tajikistan             21.7
# 172 Tanzania               29.6
# 173 Thailand                6.3
# 174 The Bahamas             9.4
# 175 Timor-Leste            32.2
# 176 Togo                   38.4
# 177 Tonga                  11.8
# 178 Trinidad and Tobago    15.1
# 179 Tunisia                11.3
# 180 Turkey                 18.4
# 181 Turkmenistan           35.9
# 182 Tuvalu                 27.8
# 183 Uganda                 28.5
# 184 Ukraine                 8.7
# 185 United Arab Emirates    5.0
# 186 United Kingdom          3.8
# 187 United States           5.1
# 188 Uruguay                 8.0
# 189 Uzbekistan             18.2
# 190 Vanuatu                13.7
# 191 Venezuela              13.9
# 192 Vietnam                14.1
# 193 West Bank              15.1
# 194 Yemen                  44.6
# 195 Zambia                 35.6
# 196 Zimbabwe               33.4
#     Region.x                          Expected_Years_To_Live
# 1   South Asia                        54.4
# 2   Europe                            79.9
# 3   Africa                            77.9
# 4   Europe                            83.8
# 5   Africa                            62.9
# 6   Central America and the Caribbean 78.3
# 7   South America                     78.8
# 8   Central Asia                      76.7
# 9   Australia and Oceania             83.5
# 10  Europe                            82.7
# 11  Central Asia                      75.9
# 12  Middle East                       80.4
# 13  South Asia                        75.2
# 14  Central America and the Caribbean 79.0
# 15  Europe                            74.7
# 16  Europe                            82.3
# 17  Central America and the Caribbean 74.3
# 18  Africa                            63.0
# 19  South Asia                        73.7
# 20  South America                     72.5
# 21  Europe                            78.5
# 22  Africa                            66.4
# 23  South America                     76.3
# 24  East and Southeast Asia           78.9
# 25  Europe                            76.1
# 26  Africa                            64.2
# 27  East and Southeast Asia           70.3
# 28  Africa                            68.1
# 29  Africa                            74.3
# 30  East and Southeast Asia           71.4
# ⋮   ⋮                                 ⋮
# 167 South America                     72.7
# 168 Europe                            82.9
# 169 Europe                            83.9
# 170 Middle East                       74.8
# 171 Central Asia                      71.9
# 172 Africa                            70.8
# 173 East and Southeast Asia           78.2
# 174 Central America and the Caribbean 76.7
# 175 East and Southeast Asia           70.5
# 176 Africa                            72.1
# 177 Australia and Oceania             78.0
# 178 Central America and the Caribbean 76.5
# 179 Africa                            77.3
# 180 Middle East                       76.7
# 181 Central Asia                      72.4
# 182 Australia and Oceania             69.0
# 183 Africa                            69.7
# 184 Europe                            70.5
# 185 Middle East                       79.9
# 186 Europe                            82.2
# 187 North America                     80.9
# 188 South America                     78.9
# 189 Central Asia                      76.2
# 190 Australia and Oceania             75.7
# 191 South America                     74.5
# 192 East and Southeast Asia           76.1
# 193 Middle East                       76.5
# 194 Middle East                       68.2
# 195 Africa                            66.9
# 196 Africa                            67.2
#     Region.y                          Deaths_Per_100K_Live_Births
# 1   South Asia                        521
# 2   Europe                              7
# 3   Africa                             62
# 4   Europe                             11
# 5   Africa                            183
# 6   Central America and the Caribbean  35
# 7   South America                      33
# 8   Central Asia                       19
# 9   Australia and Oceania               2
# 10  Europe                              6
# 11  Central Asia                       18
# 12  Middle East                        17
# 13  South Asia                        115
# 14  Central America and the Caribbean  35
# 15  Europe                              1
# 16  Europe                              4
# 17  Central America and the Caribbean  67
# 18  Africa                            518
# 19  South Asia                         47
# 20  South America                     146
# 21  Europe                              6
# 22  Africa                            155
# 23  South America                      67
# 24  East and Southeast Asia            36
# 25  Europe                              6
# 26  Africa                            242
# 27  East and Southeast Asia           185
# 28  Africa                            392
# 29  Africa                             40
# 30  East and Southeast Asia           137
# ⋮   ⋮                                 ⋮
# 167 South America                      84
# 168 Europe                              4
# 169 Europe                              5
# 170 Middle East                        20
# 171 Central Asia                       14
# 172 Africa                            276
# 173 East and Southeast Asia            34
# 174 Central America and the Caribbean  76
# 175 East and Southeast Asia           192
# 176 Africa                            349
# 177 Australia and Oceania              67
# 178 Central America and the Caribbean  54
# 179 Africa                             36
# 180 Middle East                        15
# 181 Central Asia                        5
# 182 Australia and Oceania             170
# 183 Africa                            170
# 184 Europe                             15
# 185 Middle East                         3
# 186 Europe                              8
# 187 North America                      17
# 188 South America                      15
# 189 Central Asia                       26
# 190 Australia and Oceania             100
# 191 South America                     227
# 192 East and Southeast Asia            48
# 193 Middle East                        16
# 194 Middle East                       118
# 195 Africa                             85
# 196 Africa                            358
#     Region
# 1   South Asia
# 2   Europe
# 3   Africa
# 4   Europe
# 5   Africa
# 6   Central America and the Caribbean
# 7   South America
# 8   Central Asia
# 9   Australia and Oceania
# 10  Europe
# 11  Central Asia
# 12  Middle East
# 13  South Asia
# 14  Central America and the Caribbean
# 15  Europe
# 16  Europe
# 17  Central America and the Caribbean
# 18  Africa
# 19  South Asia
# 20  South America
# 21  Europe
# 22  Africa
# 23  South America
# 24  East and Southeast Asia
# 25  Europe
# 26  Africa
# 27  East and Southeast Asia
# 28  Africa
# 29  Africa
# 30  East and Southeast Asia
# ⋮   ⋮
# 167 South America
# 168 Europe
# 169 Europe
# 170 Middle East
# 171 Central Asia
# 172 Africa
# 173 East and Southeast Asia
# 174 Central America and the Caribbean
# 175 East and Southeast Asia
# 176 Africa
# 177 Australia and Oceania
# 178 Central America and the Caribbean
# 179 Africa
# 180 Middle East
# 181 Central Asia
# 182 Australia and Oceania
# 183 Africa
# 184 Europe
# 185 Middle East
# 186 Europe
# 187 North America
# 188 South America
# 189 Central Asia
# 190 Australia and Oceania
# 191 South America
# 192 East and Southeast Asia
# 193 Middle East
# 194 Middle East
# 195 Africa
# 196 Africa

# %%
# Remove the 'Region.x' and 'Region.y' columns from final_merged_data
final_merged_data <- subset(final_merged_data, select = -c(Region.x, Region.y))

# Display the column names after removal to verify
print("Column names of final_merged_data after removing Region.x and Region.y:")
names(final_merged_data)
# Out:
# [1] "Column names of final_merged_data after removing Region.x and Region.y:"
# [1] "Country"                     "Infant_Deaths_Per_1K"
# [3] "Expected_Years_To_Live"      "Deaths_Per_100K_Live_Births"
# [5] "Region"

# %%
#this code chunk is to reorder the column names so that Region is next to Country.
# Get the current column names
current_cols <- names(final_merged_data)

# Identify the target column to move ('Region')
region_col <- "Region"

# Identify the column 'Country' after which 'Region' should be placed
country_col <- "Country"

# Create a new order for the columns
new_col_order <- c(country_col, region_col, setdiff(current_cols, c(country_col, region_col)))

# Reorder the DataFrame columns
final_merged_data <- final_merged_data[, new_col_order]

# Display the new column names to verify the order
print("Column names after reordering:")
names(final_merged_data)
# Out:
# [1] "Column names after reordering:"
# [1] "Country"                     "Region"
# [3] "Infant_Deaths_Per_1K"        "Expected_Years_To_Live"
# [5] "Deaths_Per_100K_Live_Births"

# %%
#provide a visual of the changed columns for additional verfication.
final_merged_data
# Out:
#     Country                Region
# 1   Afghanistan            South Asia
# 2   Albania                Europe
# 3   Algeria                Africa
# 4   Andorra                Europe
# 5   Angola                 Africa
# 6   Antigua and Barbuda    Central America and the Caribbean
# 7   Argentina              South America
# 8   Armenia                Central Asia
# 9   Australia              Australia and Oceania
# 10  Austria                Europe
# 11  Azerbaijan             Central Asia
# 12  Bahrain                Middle East
# 13  Bangladesh             South Asia
# 14  Barbados               Central America and the Caribbean
# 15  Belarus                Europe
# 16  Belgium                Europe
# 17  Belize                 Central America and the Caribbean
# 18  Benin                  Africa
# 19  Bhutan                 South Asia
# 20  Bolivia                South America
# 21  Bosnia and Herzegovina Europe
# 22  Botswana               Africa
# 23  Brazil                 South America
# 24  Brunei                 East and Southeast Asia
# 25  Bulgaria               Europe
# 26  Burkina Faso           Africa
# 27  Burma                  East and Southeast Asia
# 28  Burundi                Africa
# 29  Cabo Verde             Africa
# 30  Cambodia               East and Southeast Asia
# ⋮   ⋮                      ⋮
# 167 Suriname               South America
# 168 Sweden                 Europe
# 169 Switzerland            Europe
# 170 Syria                  Middle East
# 171 Tajikistan             Central Asia
# 172 Tanzania               Africa
# 173 Thailand               East and Southeast Asia
# 174 The Bahamas            Central America and the Caribbean
# 175 Timor-Leste            East and Southeast Asia
# 176 Togo                   Africa
# 177 Tonga                  Australia and Oceania
# 178 Trinidad and Tobago    Central America and the Caribbean
# 179 Tunisia                Africa
# 180 Turkey                 Middle East
# 181 Turkmenistan           Central Asia
# 182 Tuvalu                 Australia and Oceania
# 183 Uganda                 Africa
# 184 Ukraine                Europe
# 185 United Arab Emirates   Middle East
# 186 United Kingdom         Europe
# 187 United States          North America
# 188 Uruguay                South America
# 189 Uzbekistan             Central Asia
# 190 Vanuatu                Australia and Oceania
# 191 Venezuela              South America
# 192 Vietnam                East and Southeast Asia
# 193 West Bank              Middle East
# 194 Yemen                  Middle East
# 195 Zambia                 Africa
# 196 Zimbabwe               Africa
#     Infant_Deaths_Per_1K Expected_Years_To_Live Deaths_Per_100K_Live_Births
# 1   101.3                54.4                   521
# 2    10.3                79.9                     7
# 3    18.7                77.9                    62
# 4     3.3                83.8                    11
# 5    55.6                62.9                   183
# 6    13.6                78.3                    35
# 7     9.0                78.8                    33
# 8    11.6                76.7                    19
# 9     2.9                83.5                     2
# 10    3.2                82.7                     6
# 11   10.9                75.9                    18
# 12    9.7                80.4                    17
# 13   28.8                75.2                   115
# 14    9.6                79.0                    35
# 15    2.1                74.7                     1
# 16    3.1                82.3                     4
# 17   11.3                74.3                    67
# 18   52.9                63.0                   518
# 19   24.3                73.7                    47
# 20   22.3                72.5                   146
# 21    5.0                78.5                     6
# 22   23.7                66.4                   155
# 23   12.9                76.3                    67
# 24   10.0                78.9                    36
# 25    7.7                76.1                     6
# 26   47.0                64.2                   242
# 27   32.1                70.3                   185
# 28   35.7                68.1                   392
# 29   22.4                74.3                    40
# 30   27.9                71.4                   137
# ⋮   ⋮                    ⋮                      ⋮
# 167 29.6                 72.7                    84
# 168  2.3                 82.9                     4
# 169  3.0                 83.9                     5
# 170 15.1                 74.8                    20
# 171 21.7                 71.9                    14
# 172 29.6                 70.8                   276
# 173  6.3                 78.2                    34
# 174  9.4                 76.7                    76
# 175 32.2                 70.5                   192
# 176 38.4                 72.1                   349
# 177 11.8                 78.0                    67
# 178 15.1                 76.5                    54
# 179 11.3                 77.3                    36
# 180 18.4                 76.7                    15
# 181 35.9                 72.4                     5
# 182 27.8                 69.0                   170
# 183 28.5                 69.7                   170
# 184  8.7                 70.5                    15
# 185  5.0                 79.9                     3
# 186  3.8                 82.2                     8
# 187  5.1                 80.9                    17
# 188  8.0                 78.9                    15
# 189 18.2                 76.2                    26
# 190 13.7                 75.7                   100
# 191 13.9                 74.5                   227
# 192 14.1                 76.1                    48
# 193 15.1                 76.5                    16
# 194 44.6                 68.2                   118
# 195 35.6                 66.9                    85
# 196 33.4                 67.2                   358

# %%
#saving as an RDS file
saveRDS(final_merged_data,"Final_Merged_Data_HW4")

# %%
#reading to verify
Final_Merged_Data_HW4RDS=readRDS("Final_Merged_Data_HW4")
str(Final_Merged_Data_HW4RDS)
# Out:
# 'data.frame':	196 obs. of  5 variables:
#  $ Country                    : chr  "Afghanistan" "Albania" "Algeria" "Andorra" ...
#  $ Region                     : chr  "South Asia" "Europe" "Africa" "Europe" ...
#  $ Infant_Deaths_Per_1K       : num  101.3 10.3 18.7 3.3 55.6 ...
#  $ Expected_Years_To_Live     : num  54.4 79.9 77.9 83.8 62.9 78.3 78.8 76.7 83.5 82.7 ...
#  $ Deaths_Per_100K_Live_Births: int  521 7 62 11 183 35 33 19 2 6 ...

# %%
#saving as CSV file and reading to verify
write.csv(final_merged_data,"Final_Merged_Data2.csv", row.names=FALSE)
Final_Merged_Data2=read.csv("Final_Merged_Data2.csv")
str(Final_Merged_Data2)
# Out:
# 'data.frame':	196 obs. of  5 variables:
#  $ Country                    : chr  "Afghanistan" "Albania" "Algeria" "Andorra" ...
#  $ Region                     : chr  "South Asia" "Europe" "Africa" "Europe" ...
#  $ Infant_Deaths_Per_1K       : num  101.3 10.3 18.7 3.3 55.6 ...
#  $ Expected_Years_To_Live     : num  54.4 79.9 77.9 83.8 62.9 78.3 78.8 76.7 83.5 82.7 ...
#  $ Deaths_Per_100K_Live_Births: int  521 7 62 11 183 35 33 19 2 6 ...

# %%
#EXERCISE 2

# %%
#read the data file for the next exercise
read=final_merged_data

# %%
#provide data types to confirm file is still being read correctly.
str(final_merged_data)
# Out:
# 'data.frame':	196 obs. of  5 variables:
#  $ Country                    : chr  "Afghanistan" "Albania" "Algeria" "Andorra" ...
#  $ Region                     : chr  "South Asia" "Europe" "Africa" "Europe" ...
#  $ Infant_Deaths_Per_1K       : num  101.3 10.3 18.7 3.3 55.6 ...
#  $ Expected_Years_To_Live     : num  54.4 79.9 77.9 83.8 62.9 78.3 78.8 76.7 83.5 82.7 ...
#  $ Deaths_Per_100K_Live_Births: int  521 7 62 11 183 35 33 19 2 6 ...

# %%
#show first 20 rows of data for further verfication.
head(final_merged_data,20)
# Out:
#    Country             Region                            Infant_Deaths_Per_1K
# 1  Afghanistan         South Asia                        101.3
# 2  Albania             Europe                             10.3
# 3  Algeria             Africa                             18.7
# 4  Andorra             Europe                              3.3
# 5  Angola              Africa                             55.6
# 6  Antigua and Barbuda Central America and the Caribbean  13.6
# 7  Argentina           South America                       9.0
# 8  Armenia             Central Asia                       11.6
# 9  Australia           Australia and Oceania               2.9
# 10 Austria             Europe                              3.2
# 11 Azerbaijan          Central Asia                       10.9
# 12 Bahrain             Middle East                         9.7
# 13 Bangladesh          South Asia                         28.8
# 14 Barbados            Central America and the Caribbean   9.6
# 15 Belarus             Europe                              2.1
# 16 Belgium             Europe                              3.1
# 17 Belize              Central America and the Caribbean  11.3
# 18 Benin               Africa                             52.9
# 19 Bhutan              South Asia                         24.3
# 20 Bolivia             South America                      22.3
#    Expected_Years_To_Live Deaths_Per_100K_Live_Births
# 1  54.4                   521
# 2  79.9                     7
# 3  77.9                    62
# 4  83.8                    11
# 5  62.9                   183
# 6  78.3                    35
# 7  78.8                    33
# 8  76.7                    19
# 9  83.5                     2
# 10 82.7                     6
# 11 75.9                    18
# 12 80.4                    17
# 13 75.2                   115
# 14 79.0                    35
# 15 74.7                     1
# 16 82.3                     4
# 17 74.3                    67
# 18 63.0                   518
# 19 73.7                    47
# 20 72.5                   146

# %%
#downloading dplyr library needed for data aggregation
library(dplyr)

# Group the data by 'Region' and calculate the sum of numerical columns.  I chose sum, because I want to know the death data by region.
aggregated_data_by_region <- final_merged_data %>%
  group_by(Region) %>%
  summarise(
    Total_Infant_Deaths_Per_1K = sum(Infant_Deaths_Per_1K, na.rm = TRUE),
    Total_Expected_Years_To_Live = sum(Expected_Years_To_Live, na.rm = TRUE),
    Total_Deaths_Per_100K_Live_Births = sum(Deaths_Per_100K_Live_Births, na.rm = TRUE)
  )

# Display the aggregated data for verfication purposes.
print("Aggregated data by Region (Totals):")
print(aggregated_data_by_region)
# Out:
# [1] "Aggregated data by Region (Totals):"
# # A tibble: 10 × 4
#    Region   Total_Infant_Deaths_…¹ Total_Expected_Years…² Total_Deaths_Per_100…³
#    <chr>                     <dbl>                  <dbl>                  <int>
#  1 Africa                   2187.                   3622.                  15775
#  2 Austral…                  212.                   1057.                   1326
#  3 Central…                  277.                   1607.                   1454
#  4 Central…                  159                     664.                    163
#  5 East an…                  284.                   1285.                   1320
#  6 Europe                    182.                   3365.                    294
#  7 Middle …                  218.                   1235.                    367
#  8 North A…                   21.5                   240.                     71
#  9 South A…                  179.                    904.                    880
# 10 South A…                  292.                    569                    1110
# # ℹ abbreviated names: ¹​Total_Infant_Deaths_Per_1K,
# #   ²​Total_Expected_Years_To_Live, ³​Total_Deaths_Per_100K_Live_Births

# %%
#formatted veiw for additional verfication.
aggregated_data_by_region
# Out:
#    Region                            Total_Infant_Deaths_Per_1K
# 1  Africa                            2187.1
# 2  Australia and Oceania              212.1
# 3  Central America and the Caribbean  276.9
# 4  Central Asia                       159.0
# 5  East and Southeast Asia            284.5
# 6  Europe                             181.8
# 7  Middle East                        217.9
# 8  North America                       21.5
# 9  South America                      178.8
# 10 South Asia                         291.5
#    Total_Expected_Years_To_Live Total_Deaths_Per_100K_Live_Births
# 1  3621.7                       15775
# 2  1056.9                        1326
# 3  1607.4                        1454
# 4   664.4                         163
# 5  1284.9                        1320
# 6  3365.2                         294
# 7  1234.6                         367
# 8   239.7                          71
# 9   903.9                         880
# 10  569.0                        1110

# %%
#save as RDS file
saveRDS(aggregated_data_by_region,"aggregated_data_by_regionwHW4")

# %%
#read the file to verify
aggregated_data_by_region=readRDS("aggregated_data_by_regionwHW4")
str(aggregated_data_by_region)
# Out:
# tibble [10 × 4] (S3: tbl_df/tbl/data.frame)
#  $ Region                           : chr [1:10] "Africa" "Australia and Oceania" "Central America and the Caribbean" "Central Asia" ...
#  $ Total_Infant_Deaths_Per_1K       : num [1:10] 2187 212 277 159 284 ...
#  $ Total_Expected_Years_To_Live     : num [1:10] 3622 1057 1607 664 1285 ...
#  $ Total_Deaths_Per_100K_Live_Births: int [1:10] 15775 1326 1454 163 1320 294 367 71 880 1110

# %%
#save as CSV and verify per homework instructions
write.csv(aggregated_data_by_region,"aggregated_data_by_region2.csv", row.names=FALSE)
aggregated_data_by_region=read.csv("aggregated_data_by_region2.csv")
str(aggregated_data_by_region)
# Out:
# 'data.frame':	10 obs. of  4 variables:
#  $ Region                           : chr  "Africa" "Australia and Oceania" "Central America and the Caribbean" "Central Asia" ...
#  $ Total_Infant_Deaths_Per_1K       : num  2187 212 277 159 284 ...
#  $ Total_Expected_Years_To_Live     : num  3622 1057 1607 664 1285 ...
#  $ Total_Deaths_Per_100K_Live_Births: int  15775 1326 1454 163 1320 294 367 71 880 1110

# %%
#EXERCISE 3

# %%
#reading the data frame from exercise 1.
read=final_merged_data

# %%
#formatted view for verification that the data continues to display as expected.
final_merged_data
# Out:
#     Country                Region
# 1   Afghanistan            South Asia
# 2   Albania                Europe
# 3   Algeria                Africa
# 4   Andorra                Europe
# 5   Angola                 Africa
# 6   Antigua and Barbuda    Central America and the Caribbean
# 7   Argentina              South America
# 8   Armenia                Central Asia
# 9   Australia              Australia and Oceania
# 10  Austria                Europe
# 11  Azerbaijan             Central Asia
# 12  Bahrain                Middle East
# 13  Bangladesh             South Asia
# 14  Barbados               Central America and the Caribbean
# 15  Belarus                Europe
# 16  Belgium                Europe
# 17  Belize                 Central America and the Caribbean
# 18  Benin                  Africa
# 19  Bhutan                 South Asia
# 20  Bolivia                South America
# 21  Bosnia and Herzegovina Europe
# 22  Botswana               Africa
# 23  Brazil                 South America
# 24  Brunei                 East and Southeast Asia
# 25  Bulgaria               Europe
# 26  Burkina Faso           Africa
# 27  Burma                  East and Southeast Asia
# 28  Burundi                Africa
# 29  Cabo Verde             Africa
# 30  Cambodia               East and Southeast Asia
# ⋮   ⋮                      ⋮
# 167 Suriname               South America
# 168 Sweden                 Europe
# 169 Switzerland            Europe
# 170 Syria                  Middle East
# 171 Tajikistan             Central Asia
# 172 Tanzania               Africa
# 173 Thailand               East and Southeast Asia
# 174 The Bahamas            Central America and the Caribbean
# 175 Timor-Leste            East and Southeast Asia
# 176 Togo                   Africa
# 177 Tonga                  Australia and Oceania
# 178 Trinidad and Tobago    Central America and the Caribbean
# 179 Tunisia                Africa
# 180 Turkey                 Middle East
# 181 Turkmenistan           Central Asia
# 182 Tuvalu                 Australia and Oceania
# 183 Uganda                 Africa
# 184 Ukraine                Europe
# 185 United Arab Emirates   Middle East
# 186 United Kingdom         Europe
# 187 United States          North America
# 188 Uruguay                South America
# 189 Uzbekistan             Central Asia
# 190 Vanuatu                Australia and Oceania
# 191 Venezuela              South America
# 192 Vietnam                East and Southeast Asia
# 193 West Bank              Middle East
# 194 Yemen                  Middle East
# 195 Zambia                 Africa
# 196 Zimbabwe               Africa
#     Infant_Deaths_Per_1K Expected_Years_To_Live Deaths_Per_100K_Live_Births
# 1   101.3                54.4                   521
# 2    10.3                79.9                     7
# 3    18.7                77.9                    62
# 4     3.3                83.8                    11
# 5    55.6                62.9                   183
# 6    13.6                78.3                    35
# 7     9.0                78.8                    33
# 8    11.6                76.7                    19
# 9     2.9                83.5                     2
# 10    3.2                82.7                     6
# 11   10.9                75.9                    18
# 12    9.7                80.4                    17
# 13   28.8                75.2                   115
# 14    9.6                79.0                    35
# 15    2.1                74.7                     1
# 16    3.1                82.3                     4
# 17   11.3                74.3                    67
# 18   52.9                63.0                   518
# 19   24.3                73.7                    47
# 20   22.3                72.5                   146
# 21    5.0                78.5                     6
# 22   23.7                66.4                   155
# 23   12.9                76.3                    67
# 24   10.0                78.9                    36
# 25    7.7                76.1                     6
# 26   47.0                64.2                   242
# 27   32.1                70.3                   185
# 28   35.7                68.1                   392
# 29   22.4                74.3                    40
# 30   27.9                71.4                   137
# ⋮   ⋮                    ⋮                      ⋮
# 167 29.6                 72.7                    84
# 168  2.3                 82.9                     4
# 169  3.0                 83.9                     5
# 170 15.1                 74.8                    20
# 171 21.7                 71.9                    14
# 172 29.6                 70.8                   276
# 173  6.3                 78.2                    34
# 174  9.4                 76.7                    76
# 175 32.2                 70.5                   192
# 176 38.4                 72.1                   349
# 177 11.8                 78.0                    67
# 178 15.1                 76.5                    54
# 179 11.3                 77.3                    36
# 180 18.4                 76.7                    15
# 181 35.9                 72.4                     5
# 182 27.8                 69.0                   170
# 183 28.5                 69.7                   170
# 184  8.7                 70.5                    15
# 185  5.0                 79.9                     3
# 186  3.8                 82.2                     8
# 187  5.1                 80.9                    17
# 188  8.0                 78.9                    15
# 189 18.2                 76.2                    26
# 190 13.7                 75.7                   100
# 191 13.9                 74.5                   227
# 192 14.1                 76.1                    48
# 193 15.1                 76.5                    16
# 194 44.6                 68.2                   118
# 195 35.6                 66.9                    85
# 196 33.4                 67.2                   358

# %%
#code chunk to conver the data from wide to long format.  Combining all non-region/country columns into a 'Death Type' column.  Values column is designated as "Deaths", which are the number of deaths per each death type.
Merged_Data_Long=tidyr::pivot_longer(data=final_merged_data,
                                cols=c(Infant_Deaths_Per_1K, Expected_Years_To_Live, Deaths_Per_100K_Live_Births),
                                names_to = "Death Type",
                                values_to = "Deaths")

#remove the region column
Merged_Data_Long <- subset(Merged_Data_Long, select = -c(Region))

#formatted view for verifcation of the code
Merged_Data_Long
# Out:
#     Country             Death Type                  Deaths
# 1   Afghanistan         Infant_Deaths_Per_1K        101.3
# 2   Afghanistan         Expected_Years_To_Live       54.4
# 3   Afghanistan         Deaths_Per_100K_Live_Births 521.0
# 4   Albania             Infant_Deaths_Per_1K         10.3
# 5   Albania             Expected_Years_To_Live       79.9
# 6   Albania             Deaths_Per_100K_Live_Births   7.0
# 7   Algeria             Infant_Deaths_Per_1K         18.7
# 8   Algeria             Expected_Years_To_Live       77.9
# 9   Algeria             Deaths_Per_100K_Live_Births  62.0
# 10  Andorra             Infant_Deaths_Per_1K          3.3
# 11  Andorra             Expected_Years_To_Live       83.8
# 12  Andorra             Deaths_Per_100K_Live_Births  11.0
# 13  Angola              Infant_Deaths_Per_1K         55.6
# 14  Angola              Expected_Years_To_Live       62.9
# 15  Angola              Deaths_Per_100K_Live_Births 183.0
# 16  Antigua and Barbuda Infant_Deaths_Per_1K         13.6
# 17  Antigua and Barbuda Expected_Years_To_Live       78.3
# 18  Antigua and Barbuda Deaths_Per_100K_Live_Births  35.0
# 19  Argentina           Infant_Deaths_Per_1K          9.0
# 20  Argentina           Expected_Years_To_Live       78.8
# 21  Argentina           Deaths_Per_100K_Live_Births  33.0
# 22  Armenia             Infant_Deaths_Per_1K         11.6
# 23  Armenia             Expected_Years_To_Live       76.7
# 24  Armenia             Deaths_Per_100K_Live_Births  19.0
# 25  Australia           Infant_Deaths_Per_1K          2.9
# 26  Australia           Expected_Years_To_Live       83.5
# 27  Australia           Deaths_Per_100K_Live_Births   2.0
# 28  Austria             Infant_Deaths_Per_1K          3.2
# 29  Austria             Expected_Years_To_Live       82.7
# 30  Austria             Deaths_Per_100K_Live_Births   6.0
# ⋮   ⋮                   ⋮                           ⋮
# 559 United States       Infant_Deaths_Per_1K          5.1
# 560 United States       Expected_Years_To_Live       80.9
# 561 United States       Deaths_Per_100K_Live_Births  17.0
# 562 Uruguay             Infant_Deaths_Per_1K          8.0
# 563 Uruguay             Expected_Years_To_Live       78.9
# 564 Uruguay             Deaths_Per_100K_Live_Births  15.0
# 565 Uzbekistan          Infant_Deaths_Per_1K         18.2
# 566 Uzbekistan          Expected_Years_To_Live       76.2
# 567 Uzbekistan          Deaths_Per_100K_Live_Births  26.0
# 568 Vanuatu             Infant_Deaths_Per_1K         13.7
# 569 Vanuatu             Expected_Years_To_Live       75.7
# 570 Vanuatu             Deaths_Per_100K_Live_Births 100.0
# 571 Venezuela           Infant_Deaths_Per_1K         13.9
# 572 Venezuela           Expected_Years_To_Live       74.5
# 573 Venezuela           Deaths_Per_100K_Live_Births 227.0
# 574 Vietnam             Infant_Deaths_Per_1K         14.1
# 575 Vietnam             Expected_Years_To_Live       76.1
# 576 Vietnam             Deaths_Per_100K_Live_Births  48.0
# 577 West Bank           Infant_Deaths_Per_1K         15.1
# 578 West Bank           Expected_Years_To_Live       76.5
# 579 West Bank           Deaths_Per_100K_Live_Births  16.0
# 580 Yemen               Infant_Deaths_Per_1K         44.6
# 581 Yemen               Expected_Years_To_Live       68.2
# 582 Yemen               Deaths_Per_100K_Live_Births 118.0
# 583 Zambia              Infant_Deaths_Per_1K         35.6
# 584 Zambia              Expected_Years_To_Live       66.9
# 585 Zambia              Deaths_Per_100K_Live_Births  85.0
# 586 Zimbabwe            Infant_Deaths_Per_1K         33.4
# 587 Zimbabwe            Expected_Years_To_Live       67.2
# 588 Zimbabwe            Deaths_Per_100K_Live_Births 358.0

# %%
#save as RDS file.
saveRDS(Merged_Data_Long,"Merged_Data_LongRDS")

# %%
#read RDS file for verification
Merged_Data_Long=readRDS("Merged_Data_LongRDS")
str(Merged_Data_Long)
# Out:
# tibble [588 × 3] (S3: tbl_df/tbl/data.frame)
#  $ Country   : chr [1:588] "Afghanistan" "Afghanistan" "Afghanistan" "Albania" ...
#  $ Death Type: chr [1:588] "Infant_Deaths_Per_1K" "Expected_Years_To_Live" "Deaths_Per_100K_Live_Births" "Infant_Deaths_Per_1K" ...
#  $ Deaths    : num [1:588] 101.3 54.4 521 10.3 79.9 ...

# %%
#save as CSV file and view for verification
write.csv(Merged_Data_Long,"Merged_Data_Long2.csv", row.names=FALSE)
Merged_Data_Long=read.csv("Merged_Data_Long2.csv")
str(Merged_Data_Long)
# Out:
# 'data.frame':	588 obs. of  3 variables:
#  $ Country   : chr  "Afghanistan" "Afghanistan" "Afghanistan" "Albania" ...
#  $ Death.Type: chr  "Infant_Deaths_Per_1K" "Expected_Years_To_Live" "Deaths_Per_100K_Live_Births" "Infant_Deaths_Per_1K" ...
#  $ Deaths    : num  101.3 54.4 521 10.3 79.9 ...
